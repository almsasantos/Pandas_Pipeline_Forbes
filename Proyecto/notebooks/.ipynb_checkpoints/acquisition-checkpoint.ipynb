# %%
# The first step in data cleaning is to import all libraries needed:
import pandas as pd
from sqlalchemy import create_engine

# %%
# using the relative path to create the engine:
eng = create_engine('sqlite:///../data/raw/almsasantos.db')

# Or we could use the absolute path to create the engine:
# eng = create_engine('sqlite:////home/almsasantos/Desktop/Ironhack/Project_Pandas_Pipeline/Ironhack-Module-1-Project-Pandas-Pipeline/data/raw/almsasantos.db')

# %%
business_info = pd.read_sql_table('business_info', con=eng)
display(business_info)
# Out:
#         id  Unnamed: 0                                           Source  \
# 0     9478          52                           Technology  ==> Amazon
# 1     4608          53                        Technology  ==> Microsoft
# 2     8790          54  Finance and Investments  ==> Berkshire Hathaway
# 3     1463          55                       Fashion & Retail  ==> LVMH
# 4     3517          56                         Technology  ==> Facebook
# ...    ...         ...                                              ...
# 2203  4826        2255     Fashion & Retail  ==> fashion, entertainment
# 2204  8947        2256          Manufacturing  ==> electrical equipment
# 2205  5744        2257          Manufacturing  ==> electrical equipment
# 2206  6586        2258        Manufacturing  ==> printed circuit boards
# 2207  9507        2259                     Diversified  ==> diversified
#
#            worth          worthChange  realTimeWorth  realTimePosition
# 0     112.0 BUSD     0.0 millions USD            NaN                 1
# 1      90.0 BUSD  -0.001 millions USD            NaN                 2
# 2      84.0 BUSD  -0.002 millions USD            NaN                 3
# 3      72.0 BUSD     0.0 millions USD            NaN                 4
# 4      71.0 BUSD     0.0 millions USD            NaN                 5
# ...          ...                  ...            ...               ...
# 2203    1.0 BUSD     0.0 millions USD            NaN              2134
# 2204    1.0 BUSD     nan millions USD            NaN              2134
# 2205    1.0 BUSD     0.0 millions USD            NaN              1856
# 2206    1.0 BUSD     0.0 millions USD            NaN              1978
# 2207    1.0 BUSD     nan millions USD            NaN              1978
#
# [2208 rows x 7 columns]

# %%
personal_info = pd.read_sql_table('personal_info', con=eng)
display(personal_info)
# Out:
#         id    lastName           age  Unnamed: 0 gender        country  \
# 0     9478       beZOS  54 years old          52      M  United States
# 1     4608       GATES  62 years old          53      M  United States
# 2     8790     bufFEtt  87 years old          54   None           None
# 3     1463     aRNAULt  69 years old          55   None           None
# 4     3517  zuckERBErg          1985          56   Male  United States
# ...    ...         ...           ...         ...    ...            ...
# 2203  4826        zHAO  51 years old        2255   Male          China
# 2204  8947        zhOU  55 years old        2256   None           None
# 2205  5744         zHU  51 years old        2257      M           None
# 2206  6586        zHUO  52 years old        2258      F      Hong Kong
# 2207  9507       zORLU  54 years old        2259      M         Turkey
#
#                                                   image
# 0     https://specials-images.forbesimg.com/imageser...
# 1     https://specials-images.forbesimg.com/imageser...
# 2     https://specials-images.forbesimg.com/imageser...
# 3     https://specials-images.forbesimg.com/imageser...
# 4     https://specials-images.forbesimg.com/imageser...
# ...                                                 ...
# 2203  https://specials-images.forbesimg.com/imageser...
# 2204  https://specials-images.forbesimg.com/imageser...
# 2205  https://specials-images.forbesimg.com/imageser...
# 2206  https://specials-images.forbesimg.com/imageser...
# 2207  https://specials-images.forbesimg.com/imageser...
#
# [2208 rows x 7 columns]

# %%
rank_info = pd.read_sql_table('rank_info', con=eng)
display(rank_info)
# Out:
#         id                         name  position  Unnamed: 0
# 0     3846  anant asaVABHOKHIN & FAMily       NaN           0
# 1     6478               arash FERDOwsi       NaN           1
# 2     9448     baNTHOON LAMSAM & FAMIly       NaN           2
# 3     2129       bill adDERLEY & FAMILy       NaN           3
# 4     1037            BORIS ZINGArevich       NaN           4
# ...    ...                          ...       ...         ...
# 2255  4826               zhao XIAOQiang    2204.0        2255
# 2256  8947              zhou LIANGzhang    2205.0        2256
# 2257  5744                 zHU XINGMING    2206.0        2257
# 2258  6586                     ZHUO JUn    2207.0        2258
# 2259  9507                  olgun ZORLu    2208.0        2259
#
# [2260 rows x 4 columns]

# %%
df = pd.merge(pd.merge(business_info, personal_info, on='id'), rank_info, on='id')
display(df)
# Out:
#         id  Unnamed: 0_x                                           Source  \
# 0     9478            52                           Technology  ==> Amazon
# 1     4608            53                        Technology  ==> Microsoft
# 2     8790            54  Finance and Investments  ==> Berkshire Hathaway
# 3     1463            55                       Fashion & Retail  ==> LVMH
# 4     3517            56                         Technology  ==> Facebook
# ...    ...           ...                                              ...
# 2203  4826          2255     Fashion & Retail  ==> fashion, entertainment
# 2204  8947          2256          Manufacturing  ==> electrical equipment
# 2205  5744          2257          Manufacturing  ==> electrical equipment
# 2206  6586          2258        Manufacturing  ==> printed circuit boards
# 2207  9507          2259                     Diversified  ==> diversified
#
#            worth          worthChange  realTimeWorth  realTimePosition  \
# 0     112.0 BUSD     0.0 millions USD            NaN                 1
# 1      90.0 BUSD  -0.001 millions USD            NaN                 2
# 2      84.0 BUSD  -0.002 millions USD            NaN                 3
# 3      72.0 BUSD     0.0 millions USD            NaN                 4
# 4      71.0 BUSD     0.0 millions USD            NaN                 5
# ...          ...                  ...            ...               ...
# 2203    1.0 BUSD     0.0 millions USD            NaN              2134
# 2204    1.0 BUSD     nan millions USD            NaN              2134
# 2205    1.0 BUSD     0.0 millions USD            NaN              1856
# 2206    1.0 BUSD     0.0 millions USD            NaN              1978
# 2207    1.0 BUSD     nan millions USD            NaN              1978
#
#         lastName           age  Unnamed: 0_y gender        country  \
# 0          beZOS  54 years old            52      M  United States
# 1          GATES  62 years old            53      M  United States
# 2        bufFEtt  87 years old            54   None           None
# 3        aRNAULt  69 years old            55   None           None
# 4     zuckERBErg          1985            56   Male  United States
# ...          ...           ...           ...    ...            ...
# 2203        zHAO  51 years old          2255   Male          China
# 2204        zhOU  55 years old          2256   None           None
# 2205         zHU  51 years old          2257      M           None
# 2206        zHUO  52 years old          2258      F      Hong Kong
# 2207       zORLU  54 years old          2259      M         Turkey
#
#                                                   image             name  \
# 0     https://specials-images.forbesimg.com/imageser...       JEFF BEZOS
# 1     https://specials-images.forbesimg.com/imageser...       BILL GATEs
# 2     https://specials-images.forbesimg.com/imageser...   warren BUffett
# 3     https://specials-images.forbesimg.com/imageser...  beRNARD ARNAUlt
# 4     https://specials-images.forbesimg.com/imageser...  mARK ZUCKERBErg
# ...                                                 ...              ...
# 2203  https://specials-images.forbesimg.com/imageser...   zhao XIAOQiang
# 2204  https://specials-images.forbesimg.com/imageser...  zhou LIANGzhang
# 2205  https://specials-images.forbesimg.com/imageser...     zHU XINGMING
# 2206  https://specials-images.forbesimg.com/imageser...         ZHUO JUn
# 2207  https://specials-images.forbesimg.com/imageser...      olgun ZORLu
#
#       position  Unnamed: 0
# 0          1.0          52
# 1          2.0          53
# 2          3.0          54
# 3          4.0          55
# 4          5.0          56
# ...        ...         ...
# 2203    2204.0        2255
# 2204    2205.0        2256
# 2205    2206.0        2257
# 2206    2207.0        2258
# 2207    2208.0        2259
#
# [2208 rows x 16 columns]

# %%
df.to_csv('df_to_clean')
