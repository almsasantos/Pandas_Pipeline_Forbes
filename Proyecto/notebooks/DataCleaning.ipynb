# %%
# The first step in data cleaning is to import all libraries needed:

import re
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
import matplotlib.pyplot as plt
import argparse
import datetime
import requests
from lxml import html
from bs4 import BeautifulSoup
import warnings 
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
# using the relative path to create the engine:
eng = create_engine('sqlite:///../data/raw/almsasantos.db')

# Or we could use the absolute path to create the engine:
# eng = create_engine('sqlite:////home/almsasantos/Desktop/Ironhack/Project_Pandas_Pipeline/Ironhack-Module-1-Project-Pandas-Pipeline/data/raw/almsasantos.db')

# %%
business_info = pd.read_sql_table('business_info', con=eng)
display(business_info)
# Out:
#         id  Unnamed: 0                                           Source  \
# 0     9478          52                           Technology  ==> Amazon
# 1     4608          53                        Technology  ==> Microsoft
# 2     8790          54  Finance and Investments  ==> Berkshire Hathaway
# 3     1463          55                       Fashion & Retail  ==> LVMH
# 4     3517          56                         Technology  ==> Facebook
# ...    ...         ...                                              ...
# 2203  4826        2255     Fashion & Retail  ==> fashion, entertainment
# 2204  8947        2256          Manufacturing  ==> electrical equipment
# 2205  5744        2257          Manufacturing  ==> electrical equipment
# 2206  6586        2258        Manufacturing  ==> printed circuit boards
# 2207  9507        2259                     Diversified  ==> diversified
#
#            worth          worthChange  realTimeWorth  realTimePosition
# 0     112.0 BUSD     0.0 millions USD            NaN                 1
# 1      90.0 BUSD  -0.001 millions USD            NaN                 2
# 2      84.0 BUSD  -0.002 millions USD            NaN                 3
# 3      72.0 BUSD     0.0 millions USD            NaN                 4
# 4      71.0 BUSD     0.0 millions USD            NaN                 5
# ...          ...                  ...            ...               ...
# 2203    1.0 BUSD     0.0 millions USD            NaN              2134
# 2204    1.0 BUSD     nan millions USD            NaN              2134
# 2205    1.0 BUSD     0.0 millions USD            NaN              1856
# 2206    1.0 BUSD     0.0 millions USD            NaN              1978
# 2207    1.0 BUSD     nan millions USD            NaN              1978
#
# [2208 rows x 7 columns]

# %%
business_info.describe().T
# Out:
#                    count         mean          std     min      25%     50%  \
# id                2208.0  5527.846014  2580.021263  1002.0  3334.75  5493.5
# Unnamed: 0        2208.0  1155.500000   637.539018    52.0   603.75  1155.5
# realTimeWorth        0.0          NaN          NaN     NaN      NaN     NaN
# realTimePosition  2208.0  1102.043478   630.218047     1.0   555.75  1106.5
#
#                       75%     max
# id                7790.00  9993.0
# Unnamed: 0        1707.25  2259.0
# realTimeWorth         NaN     NaN
# realTimePosition  1655.25  2153.0

# %%
# To see how many null values exist in each of column of the table business_info
business_info.isnull().sum()
# Out:
# id                     0
# Unnamed: 0             0
# Source                 0
# worth                  0
# worthChange            0
# realTimeWorth       2208
# realTimePosition       0
# dtype: int64

# %%
# Dropping column full of nulls
null_cols = business_info.isnull().sum()


null_cols = null_cols[null_cols>0]/len(business_info) *100
null_filter = null_cols >= 100

drop_cols = list(null_cols[null_filter].index)
business_info.drop(drop_cols, axis=1, inplace=True)

business_info
# Out:
#         id  Unnamed: 0                                           Source  \
# 0     9478          52                           Technology  ==> Amazon
# 1     4608          53                        Technology  ==> Microsoft
# 2     8790          54  Finance and Investments  ==> Berkshire Hathaway
# 3     1463          55                       Fashion & Retail  ==> LVMH
# 4     3517          56                         Technology  ==> Facebook
# ...    ...         ...                                              ...
# 2203  4826        2255     Fashion & Retail  ==> fashion, entertainment
# 2204  8947        2256          Manufacturing  ==> electrical equipment
# 2205  5744        2257          Manufacturing  ==> electrical equipment
# 2206  6586        2258        Manufacturing  ==> printed circuit boards
# 2207  9507        2259                     Diversified  ==> diversified
#
#            worth          worthChange  realTimePosition
# 0     112.0 BUSD     0.0 millions USD                 1
# 1      90.0 BUSD  -0.001 millions USD                 2
# 2      84.0 BUSD  -0.002 millions USD                 3
# 3      72.0 BUSD     0.0 millions USD                 4
# 4      71.0 BUSD     0.0 millions USD                 5
# ...          ...                  ...               ...
# 2203    1.0 BUSD     0.0 millions USD              2134
# 2204    1.0 BUSD     nan millions USD              2134
# 2205    1.0 BUSD     0.0 millions USD              1856
# 2206    1.0 BUSD     0.0 millions USD              1978
# 2207    1.0 BUSD     nan millions USD              1978
#
# [2208 rows x 6 columns]

# %%
business_info.drop('Unnamed: 0', axis=1 ,inplace=True)
business_info
# Out:
#         id                                           Source       worth  \
# 0     9478                           Technology  ==> Amazon  112.0 BUSD
# 1     4608                        Technology  ==> Microsoft   90.0 BUSD
# 2     8790  Finance and Investments  ==> Berkshire Hathaway   84.0 BUSD
# 3     1463                       Fashion & Retail  ==> LVMH   72.0 BUSD
# 4     3517                         Technology  ==> Facebook   71.0 BUSD
# ...    ...                                              ...         ...
# 2203  4826     Fashion & Retail  ==> fashion, entertainment    1.0 BUSD
# 2204  8947          Manufacturing  ==> electrical equipment    1.0 BUSD
# 2205  5744          Manufacturing  ==> electrical equipment    1.0 BUSD
# 2206  6586        Manufacturing  ==> printed circuit boards    1.0 BUSD
# 2207  9507                     Diversified  ==> diversified    1.0 BUSD
#
#               worthChange  realTimePosition
# 0        0.0 millions USD                 1
# 1     -0.001 millions USD                 2
# 2     -0.002 millions USD                 3
# 3        0.0 millions USD                 4
# 4        0.0 millions USD                 5
# ...                   ...               ...
# 2203     0.0 millions USD              2134
# 2204     nan millions USD              2134
# 2205     0.0 millions USD              1856
# 2206     0.0 millions USD              1978
# 2207     nan millions USD              1978
#
# [2208 rows x 5 columns]

# %%
business_info['worth'] = business_info.worth.str.replace('BUSD', '')
business_info['worthChange'] = business_info['worthChange'].str.replace('millions USD', '')
business_info
# Out:
#         id                                           Source   worth  \
# 0     9478                           Technology  ==> Amazon  112.0
# 1     4608                        Technology  ==> Microsoft   90.0
# 2     8790  Finance and Investments  ==> Berkshire Hathaway   84.0
# 3     1463                       Fashion & Retail  ==> LVMH   72.0
# 4     3517                         Technology  ==> Facebook   71.0
# ...    ...                                              ...     ...
# 2203  4826     Fashion & Retail  ==> fashion, entertainment    1.0
# 2204  8947          Manufacturing  ==> electrical equipment    1.0
# 2205  5744          Manufacturing  ==> electrical equipment    1.0
# 2206  6586        Manufacturing  ==> printed circuit boards    1.0
# 2207  9507                     Diversified  ==> diversified    1.0
#
#      worthChange  realTimePosition
# 0           0.0                  1
# 1        -0.001                  2
# 2        -0.002                  3
# 3           0.0                  4
# 4           0.0                  5
# ...          ...               ...
# 2203        0.0               2134
# 2204        nan               2134
# 2205        0.0               1856
# 2206        0.0               1978
# 2207        nan               1978
#
# [2208 rows x 5 columns]

# %%
personal_info = pd.read_sql_table('personal_info', con=eng)

# %%
personal_info.drop('Unnamed: 0', axis=1, inplace=True)

# %%
personal_info
# Out:
#         id    lastName           age gender        country  \
# 0     9478       beZOS  54 years old      M  United States
# 1     4608       GATES  62 years old      M  United States
# 2     8790     bufFEtt  87 years old   None           None
# 3     1463     aRNAULt  69 years old   None           None
# 4     3517  zuckERBErg          1985   Male  United States
# ...    ...         ...           ...    ...            ...
# 2203  4826        zHAO  51 years old   Male          China
# 2204  8947        zhOU  55 years old   None           None
# 2205  5744         zHU  51 years old      M           None
# 2206  6586        zHUO  52 years old      F      Hong Kong
# 2207  9507       zORLU  54 years old      M         Turkey
#
#                                                   image
# 0     https://specials-images.forbesimg.com/imageser...
# 1     https://specials-images.forbesimg.com/imageser...
# 2     https://specials-images.forbesimg.com/imageser...
# 3     https://specials-images.forbesimg.com/imageser...
# 4     https://specials-images.forbesimg.com/imageser...
# ...                                                 ...
# 2203  https://specials-images.forbesimg.com/imageser...
# 2204  https://specials-images.forbesimg.com/imageser...
# 2205  https://specials-images.forbesimg.com/imageser...
# 2206  https://specials-images.forbesimg.com/imageser...
# 2207  https://specials-images.forbesimg.com/imageser...
#
# [2208 rows x 6 columns]

# %%
personal_info.isnull().sum()
# Out:
# id           0
# lastName     0
# age         65
# gender      13
# country      0
# image        0
# dtype: int64

# %%
df1 = (personal_info.age.str.extract('(\d+) (\w+)', expand=True))
df1.columns = ['age', 'years old']
print(df1)
# Out:
#       age years old
# 0      54     years
# 1      62     years
# 2      87     years
# 3      69     years
# 4     NaN       NaN
# ...   ...       ...
# 2203   51     years
# 2204   55     years
# 2205   51     years
# 2206   52     years
# 2207   54     years
#
# [2208 rows x 2 columns]

# %%
personal_info = df1.combine_first(personal_info).reindex(personal_info.index)
personal_info.drop('years old', axis=1, inplace=True)
personal_info
# Out:
#        age        country gender      id  \
# 0       54  United States      M  9478.0
# 1       62  United States      M  4608.0
# 2       87           None   None  8790.0
# 3       69           None   None  1463.0
# 4     1985  United States   Male  3517.0
# ...    ...            ...    ...     ...
# 2203    51          China   Male  4826.0
# 2204    55           None   None  8947.0
# 2205    51           None      M  5744.0
# 2206    52      Hong Kong      F  6586.0
# 2207    54         Turkey      M  9507.0
#
#                                                   image    lastName
# 0     https://specials-images.forbesimg.com/imageser...       beZOS
# 1     https://specials-images.forbesimg.com/imageser...       GATES
# 2     https://specials-images.forbesimg.com/imageser...     bufFEtt
# 3     https://specials-images.forbesimg.com/imageser...     aRNAULt
# 4     https://specials-images.forbesimg.com/imageser...  zuckERBErg
# ...                                                 ...         ...
# 2203  https://specials-images.forbesimg.com/imageser...        zHAO
# 2204  https://specials-images.forbesimg.com/imageser...        zhOU
# 2205  https://specials-images.forbesimg.com/imageser...         zHU
# 2206  https://specials-images.forbesimg.com/imageser...        zHUO
# 2207  https://specials-images.forbesimg.com/imageser...       zORLU
#
# [2208 rows x 6 columns]

# %%
rank_info = pd.read_sql_table('rank_info', con=eng)

# %%
rank_info.drop('Unnamed: 0', axis=1, inplace=True)

# %%
rank_info
# Out:
#         id                         name  position
# 0     3846  anant asaVABHOKHIN & FAMily       NaN
# 1     6478               arash FERDOwsi       NaN
# 2     9448     baNTHOON LAMSAM & FAMIly       NaN
# 3     2129       bill adDERLEY & FAMILy       NaN
# 4     1037            BORIS ZINGArevich       NaN
# ...    ...                          ...       ...
# 2255  4826               zhao XIAOQiang    2204.0
# 2256  8947              zhou LIANGzhang    2205.0
# 2257  5744                 zHU XINGMING    2206.0
# 2258  6586                     ZHUO JUn    2207.0
# 2259  9507                  olgun ZORLu    2208.0
#
# [2260 rows x 3 columns]

# %%
df = pd.merge(pd.merge(business_info, personal_info, on='id'), rank_info, on='id')

# %%
df
# Out:
#         id                                           Source   worth  \
# 0     9478                           Technology  ==> Amazon  112.0
# 1     4608                        Technology  ==> Microsoft   90.0
# 2     8790  Finance and Investments  ==> Berkshire Hathaway   84.0
# 3     1463                       Fashion & Retail  ==> LVMH   72.0
# 4     3517                         Technology  ==> Facebook   71.0
# ...    ...                                              ...     ...
# 2203  4826     Fashion & Retail  ==> fashion, entertainment    1.0
# 2204  8947          Manufacturing  ==> electrical equipment    1.0
# 2205  5744          Manufacturing  ==> electrical equipment    1.0
# 2206  6586        Manufacturing  ==> printed circuit boards    1.0
# 2207  9507                     Diversified  ==> diversified    1.0
#
#      worthChange  realTimePosition   age        country gender  \
# 0           0.0                  1    54  United States      M
# 1        -0.001                  2    62  United States      M
# 2        -0.002                  3    87           None   None
# 3           0.0                  4    69           None   None
# 4           0.0                  5  1985  United States   Male
# ...          ...               ...   ...            ...    ...
# 2203        0.0               2134    51          China   Male
# 2204        nan               2134    55           None   None
# 2205        0.0               1856    51           None      M
# 2206        0.0               1978    52      Hong Kong      F
# 2207        nan               1978    54         Turkey      M
#
#                                                   image    lastName  \
# 0     https://specials-images.forbesimg.com/imageser...       beZOS
# 1     https://specials-images.forbesimg.com/imageser...       GATES
# 2     https://specials-images.forbesimg.com/imageser...     bufFEtt
# 3     https://specials-images.forbesimg.com/imageser...     aRNAULt
# 4     https://specials-images.forbesimg.com/imageser...  zuckERBErg
# ...                                                 ...         ...
# 2203  https://specials-images.forbesimg.com/imageser...        zHAO
# 2204  https://specials-images.forbesimg.com/imageser...        zhOU
# 2205  https://specials-images.forbesimg.com/imageser...         zHU
# 2206  https://specials-images.forbesimg.com/imageser...        zHUO
# 2207  https://specials-images.forbesimg.com/imageser...       zORLU
#
#                  name  position
# 0          JEFF BEZOS       1.0
# 1          BILL GATEs       2.0
# 2      warren BUffett       3.0
# 3     beRNARD ARNAUlt       4.0
# 4     mARK ZUCKERBErg       5.0
# ...               ...       ...
# 2203   zhao XIAOQiang    2204.0
# 2204  zhou LIANGzhang    2205.0
# 2205     zHU XINGMING    2206.0
# 2206         ZHUO JUn    2207.0
# 2207      olgun ZORLu    2208.0
#
# [2208 rows x 12 columns]

# %%
df = df[['id', 'name', 'lastName', 'age', 'gender', 'country', 'position', 'realTimePosition', 'Source', 'worth', 'worthChange', 'image']]
df
# Out:
#         id             name    lastName   age gender        country  position  \
# 0     9478       JEFF BEZOS       beZOS    54      M  United States       1.0
# 1     4608       BILL GATEs       GATES    62      M  United States       2.0
# 2     8790   warren BUffett     bufFEtt    87   None           None       3.0
# 3     1463  beRNARD ARNAUlt     aRNAULt    69   None           None       4.0
# 4     3517  mARK ZUCKERBErg  zuckERBErg  1985   Male  United States       5.0
# ...    ...              ...         ...   ...    ...            ...       ...
# 2203  4826   zhao XIAOQiang        zHAO    51   Male          China    2204.0
# 2204  8947  zhou LIANGzhang        zhOU    55   None           None    2205.0
# 2205  5744     zHU XINGMING         zHU    51      M           None    2206.0
# 2206  6586         ZHUO JUn        zHUO    52      F      Hong Kong    2207.0
# 2207  9507      olgun ZORLu       zORLU    54      M         Turkey    2208.0
#
#       realTimePosition                                           Source  \
# 0                    1                           Technology  ==> Amazon
# 1                    2                        Technology  ==> Microsoft
# 2                    3  Finance and Investments  ==> Berkshire Hathaway
# 3                    4                       Fashion & Retail  ==> LVMH
# 4                    5                         Technology  ==> Facebook
# ...                ...                                              ...
# 2203              2134     Fashion & Retail  ==> fashion, entertainment
# 2204              2134          Manufacturing  ==> electrical equipment
# 2205              1856          Manufacturing  ==> electrical equipment
# 2206              1978        Manufacturing  ==> printed circuit boards
# 2207              1978                     Diversified  ==> diversified
#
#        worth worthChange                                              image
# 0     112.0         0.0   https://specials-images.forbesimg.com/imageser...
# 1      90.0      -0.001   https://specials-images.forbesimg.com/imageser...
# 2      84.0      -0.002   https://specials-images.forbesimg.com/imageser...
# 3      72.0         0.0   https://specials-images.forbesimg.com/imageser...
# 4      71.0         0.0   https://specials-images.forbesimg.com/imageser...
# ...      ...         ...                                                ...
# 2203    1.0         0.0   https://specials-images.forbesimg.com/imageser...
# 2204    1.0         nan   https://specials-images.forbesimg.com/imageser...
# 2205    1.0         0.0   https://specials-images.forbesimg.com/imageser...
# 2206    1.0         0.0   https://specials-images.forbesimg.com/imageser...
# 2207    1.0         nan   https://specials-images.forbesimg.com/imageser...
#
# [2208 rows x 12 columns]

# %%
df[['work_field', 'company']] = df.Source.str.split(' ==> ', expand=True)
df.drop('Source', axis=1, inplace=True)

# %%
df = df.rename(columns={'name': 'first_name', 'lastName': 'last_name', 'realTimePosition': \
                        'real_time_position', 'worth': 'worth(BUSD)', 'worthChange': 'worth(millions_USD)'})
df = df[['id', 'first_name', 'last_name', 'age', 'gender', 'country', 'position', 'real_time_position', \
              'worth(BUSD)', 'worth(millions_USD)', 'work_field', 'company', 'image']]

display(df)
# Out:
#         id       first_name   last_name   age gender        country  position  \
# 0     9478       JEFF BEZOS       beZOS    54      M  United States       1.0
# 1     4608       BILL GATEs       GATES    62      M  United States       2.0
# 2     8790   warren BUffett     bufFEtt    87   None           None       3.0
# 3     1463  beRNARD ARNAUlt     aRNAULt    69   None           None       4.0
# 4     3517  mARK ZUCKERBErg  zuckERBErg  1985   Male  United States       5.0
# ...    ...              ...         ...   ...    ...            ...       ...
# 2203  4826   zhao XIAOQiang        zHAO    51   Male          China    2204.0
# 2204  8947  zhou LIANGzhang        zhOU    55   None           None    2205.0
# 2205  5744     zHU XINGMING         zHU    51      M           None    2206.0
# 2206  6586         ZHUO JUn        zHUO    52      F      Hong Kong    2207.0
# 2207  9507      olgun ZORLu       zORLU    54      M         Turkey    2208.0
#
#       real_time_position worth(BUSD) worth(millions_USD)  \
# 0                      1      112.0                 0.0
# 1                      2       90.0              -0.001
# 2                      3       84.0              -0.002
# 3                      4       72.0                 0.0
# 4                      5       71.0                 0.0
# ...                  ...         ...                 ...
# 2203                2134        1.0                 0.0
# 2204                2134        1.0                 nan
# 2205                1856        1.0                 0.0
# 2206                1978        1.0                 0.0
# 2207                1978        1.0                 nan
#
#                     work_field                 company  \
# 0                  Technology                   Amazon
# 1                  Technology                Microsoft
# 2     Finance and Investments       Berkshire Hathaway
# 3            Fashion & Retail                     LVMH
# 4                  Technology                 Facebook
# ...                        ...                     ...
# 2203         Fashion & Retail   fashion, entertainment
# 2204            Manufacturing     electrical equipment
# 2205            Manufacturing     electrical equipment
# 2206            Manufacturing   printed circuit boards
# 2207              Diversified              diversified
#
#                                                   image
# 0     https://specials-images.forbesimg.com/imageser...
# 1     https://specials-images.forbesimg.com/imageser...
# 2     https://specials-images.forbesimg.com/imageser...
# 3     https://specials-images.forbesimg.com/imageser...
# 4     https://specials-images.forbesimg.com/imageser...
# ...                                                 ...
# 2203  https://specials-images.forbesimg.com/imageser...
# 2204  https://specials-images.forbesimg.com/imageser...
# 2205  https://specials-images.forbesimg.com/imageser...
# 2206  https://specials-images.forbesimg.com/imageser...
# 2207  https://specials-images.forbesimg.com/imageser...
#
# [2208 rows x 13 columns]

# %%
def column_title(df, ls):
    for i in ls:
        df.update(df[i].str.title())
    return df
ls_cols = ['first_name', 'last_name', 'company']
column_title(df, ls_cols)
# Out:
#         id       first_name   last_name   age gender        country  position  \
# 0     9478       Jeff Bezos       Bezos    54      M  United States       1.0
# 1     4608       Bill Gates       Gates    62      M  United States       2.0
# 2     8790   Warren Buffett     Buffett    87   None           None       3.0
# 3     1463  Bernard Arnault     Arnault    69   None           None       4.0
# 4     3517  Mark Zuckerberg  Zuckerberg  1985   Male  United States       5.0
# ...    ...              ...         ...   ...    ...            ...       ...
# 2203  4826   Zhao Xiaoqiang        Zhao    51   Male          China    2204.0
# 2204  8947  Zhou Liangzhang        Zhou    55   None           None    2205.0
# 2205  5744     Zhu Xingming         Zhu    51      M           None    2206.0
# 2206  6586         Zhuo Jun        Zhuo    52      F      Hong Kong    2207.0
# 2207  9507      Olgun Zorlu       Zorlu    54      M         Turkey    2208.0
#
#       real_time_position worth(BUSD) worth(millions_USD)  \
# 0                      1      112.0                 0.0
# 1                      2       90.0              -0.001
# 2                      3       84.0              -0.002
# 3                      4       72.0                 0.0
# 4                      5       71.0                 0.0
# ...                  ...         ...                 ...
# 2203                2134        1.0                 0.0
# 2204                2134        1.0                 nan
# 2205                1856        1.0                 0.0
# 2206                1978        1.0                 0.0
# 2207                1978        1.0                 nan
#
#                     work_field                 company  \
# 0                  Technology                   Amazon
# 1                  Technology                Microsoft
# 2     Finance and Investments       Berkshire Hathaway
# 3            Fashion & Retail                     Lvmh
# 4                  Technology                 Facebook
# ...                        ...                     ...
# 2203         Fashion & Retail   Fashion, Entertainment
# 2204            Manufacturing     Electrical Equipment
# 2205            Manufacturing     Electrical Equipment
# 2206            Manufacturing   Printed Circuit Boards
# 2207              Diversified              Diversified
#
#                                                   image
# 0     https://specials-images.forbesimg.com/imageser...
# 1     https://specials-images.forbesimg.com/imageser...
# 2     https://specials-images.forbesimg.com/imageser...
# 3     https://specials-images.forbesimg.com/imageser...
# 4     https://specials-images.forbesimg.com/imageser...
# ...                                                 ...
# 2203  https://specials-images.forbesimg.com/imageser...
# 2204  https://specials-images.forbesimg.com/imageser...
# 2205  https://specials-images.forbesimg.com/imageser...
# 2206  https://specials-images.forbesimg.com/imageser...
# 2207  https://specials-images.forbesimg.com/imageser...
#
# [2208 rows x 13 columns]

# %%
# Since we had the first and last name in the column name, with the following code we have only the first
# name in the column name and the last name in the column lastName
df['first_name'] = [a.replace(b, '').strip() for a, b in zip(df['first_name'], df['last_name'])]

display(df)
# Out:
#         id  first_name   last_name   age gender        country  position  \
# 0     9478        Jeff       Bezos    54      M  United States       1.0
# 1     4608        Bill       Gates    62      M  United States       2.0
# 2     8790      Warren     Buffett    87   None           None       3.0
# 3     1463     Bernard     Arnault    69   None           None       4.0
# 4     3517        Mark  Zuckerberg  1985   Male  United States       5.0
# ...    ...         ...         ...   ...    ...            ...       ...
# 2203  4826   Xiaoqiang        Zhao    51   Male          China    2204.0
# 2204  8947  Liangzhang        Zhou    55   None           None    2205.0
# 2205  5744    Xingming         Zhu    51      M           None    2206.0
# 2206  6586         Jun        Zhuo    52      F      Hong Kong    2207.0
# 2207  9507       Olgun       Zorlu    54      M         Turkey    2208.0
#
#       real_time_position worth(BUSD) worth(millions_USD)  \
# 0                      1      112.0                 0.0
# 1                      2       90.0              -0.001
# 2                      3       84.0              -0.002
# 3                      4       72.0                 0.0
# 4                      5       71.0                 0.0
# ...                  ...         ...                 ...
# 2203                2134        1.0                 0.0
# 2204                2134        1.0                 nan
# 2205                1856        1.0                 0.0
# 2206                1978        1.0                 0.0
# 2207                1978        1.0                 nan
#
#                     work_field                 company  \
# 0                  Technology                   Amazon
# 1                  Technology                Microsoft
# 2     Finance and Investments       Berkshire Hathaway
# 3            Fashion & Retail                     Lvmh
# 4                  Technology                 Facebook
# ...                        ...                     ...
# 2203         Fashion & Retail   Fashion, Entertainment
# 2204            Manufacturing     Electrical Equipment
# 2205            Manufacturing     Electrical Equipment
# 2206            Manufacturing   Printed Circuit Boards
# 2207              Diversified              Diversified
#
#                                                   image
# 0     https://specials-images.forbesimg.com/imageser...
# 1     https://specials-images.forbesimg.com/imageser...
# 2     https://specials-images.forbesimg.com/imageser...
# 3     https://specials-images.forbesimg.com/imageser...
# 4     https://specials-images.forbesimg.com/imageser...
# ...                                                 ...
# 2203  https://specials-images.forbesimg.com/imageser...
# 2204  https://specials-images.forbesimg.com/imageser...
# 2205  https://specials-images.forbesimg.com/imageser...
# 2206  https://specials-images.forbesimg.com/imageser...
# 2207  https://specials-images.forbesimg.com/imageser...
#
# [2208 rows x 13 columns]

# %%
# This command is necessary to check the values we have in this series:
df['gender'].value_counts()
# Out:
# M         1127
# None       495
# Male       382
# F          155
# Female      36
# Name: gender, dtype: int64

# %%
df.gender.replace('Male', 'M', inplace=True)
df.gender.replace('Female', 'F', inplace=True)
display(df)
# Out:
#         id  first_name   last_name   age gender        country  position  \
# 0     9478        Jeff       Bezos    54      M  United States       1.0
# 1     4608        Bill       Gates    62      M  United States       2.0
# 2     8790      Warren     Buffett    87   None           None       3.0
# 3     1463     Bernard     Arnault    69   None           None       4.0
# 4     3517        Mark  Zuckerberg  1985      M  United States       5.0
# ...    ...         ...         ...   ...    ...            ...       ...
# 2203  4826   Xiaoqiang        Zhao    51      M          China    2204.0
# 2204  8947  Liangzhang        Zhou    55   None           None    2205.0
# 2205  5744    Xingming         Zhu    51      M           None    2206.0
# 2206  6586         Jun        Zhuo    52      F      Hong Kong    2207.0
# 2207  9507       Olgun       Zorlu    54      M         Turkey    2208.0
#
#       real_time_position worth(BUSD) worth(millions_USD)  \
# 0                      1      112.0                 0.0
# 1                      2       90.0              -0.001
# 2                      3       84.0              -0.002
# 3                      4       72.0                 0.0
# 4                      5       71.0                 0.0
# ...                  ...         ...                 ...
# 2203                2134        1.0                 0.0
# 2204                2134        1.0                 nan
# 2205                1856        1.0                 0.0
# 2206                1978        1.0                 0.0
# 2207                1978        1.0                 nan
#
#                     work_field                 company  \
# 0                  Technology                   Amazon
# 1                  Technology                Microsoft
# 2     Finance and Investments       Berkshire Hathaway
# 3            Fashion & Retail                     Lvmh
# 4                  Technology                 Facebook
# ...                        ...                     ...
# 2203         Fashion & Retail   Fashion, Entertainment
# 2204            Manufacturing     Electrical Equipment
# 2205            Manufacturing     Electrical Equipment
# 2206            Manufacturing   Printed Circuit Boards
# 2207              Diversified              Diversified
#
#                                                   image
# 0     https://specials-images.forbesimg.com/imageser...
# 1     https://specials-images.forbesimg.com/imageser...
# 2     https://specials-images.forbesimg.com/imageser...
# 3     https://specials-images.forbesimg.com/imageser...
# 4     https://specials-images.forbesimg.com/imageser...
# ...                                                 ...
# 2203  https://specials-images.forbesimg.com/imageser...
# 2204  https://specials-images.forbesimg.com/imageser...
# 2205  https://specials-images.forbesimg.com/imageser...
# 2206  https://specials-images.forbesimg.com/imageser...
# 2207  https://specials-images.forbesimg.com/imageser...
#
# [2208 rows x 13 columns]

# %%
# Transform all ages to correct numbers:
current_year = datetime.datetime.today().year

age = []
for i in df['age']:
    if i is not null:
        if len(i) == 4:
           age.append(str(current_year-int(i)))
        else:
            age.append(i)


df['age'] = age
display(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-64c7199ae177> in <module>
#       4 age = []
#       5 for i in df['age']:
# ----> 6     if i is not null:
#       7         if len(i) == 4:
#       8            age.append(str(current_year-int(i)))
#
# NameError: name 'null' is not defined

# %%
# The function change_types receives a list of columns of the df as an argument and will convert its type
# to float, so it's possible to operate with them.
def change_to_float_type(l):
    for i in l:
        df[i] = df[i].astype(float)
change_to_float_type(['worth(BUSD)', 'worth(millions_USD)'])

# %%
#3def change_to_int_type(l):
#    for i in l:
#        df[i] = df[i].astype(int)
#change_to_int_type(['age', 'position'])

#df.dtypes

# %%
(df.country=='None').sum()

# %%
df['diff_position'] = df['position'] - df['real_time_position']
df['name'] = df.first_name +'_'+ df.last_name
display(df)

# %%
a = list(df.loc[:,'country']=='None')
count = -1
none_country_list = []
for i in a:
    count +=1
    if i == True:
        none_country_list.append(count)
len(none_country_list)

# %%
df_work_field = pd.DataFrame(df)
df_work_field.groupby(['work_field', 'worth(BUSD)']).max().sort_values(by='work_field', ascending=False)

# %%
(df_work_field.age == '-').sum()

# %%
df_work_field.groupby(['work_field', 'worth(BUSD)']).max().sort_values(by='work_field', ascending=False)

# %%
df.loc[df['age'] == 'N', :]

# %%
df.age.hist(bins=60)
plt.xlabel('Age')
plt.ylabel('Number')
plt.title('Age distribution')
plt.show()

# %%
df.describe()

# %%
(df['country'] == 'None').sum()
