# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
df = pd.read_csv('df_file')
display(df)
# Out:
#       position first_name   last_name  age gender        country  \
# 0          1.0       Jeff       Bezos   54      M  United States
# 1          2.0       Bill       Gates   62      M  United States
# 2          3.0     Warren     Buffett   87      M  United States
# 3          4.0    Bernard     Arnault   69      M         France
# 4          5.0       Mark  Zuckerberg   34      M  United States
# ...        ...        ...         ...  ...    ...            ...
# 2203    2204.0       Zhao   Xiaoqiang   51      M          China
# 2204    2205.0       Zhou  Liangzhang   55      M          China
# 2205    2206.0        Zhu    Xingming   51      M          China
# 2206    2207.0        Jun        Zhuo   52      F      Hong Kong
# 2207    2208.0      Olgun       Zorlu   54      M         Turkey
#
#       real_time_position  worth(BUSD)  worth(millions_USD)  \
# 0                      1        112.0                0.000
# 1                      2         90.0               -0.001
# 2                      3         84.0               -0.002
# 3                      4         72.0                0.000
# 4                      5         71.0                0.000
# ...                  ...          ...                  ...
# 2203                2134          1.0                0.000
# 2204                2134          1.0                  NaN
# 2205                1856          1.0                0.000
# 2206                1978          1.0                0.000
# 2207                1978          1.0                  NaN
#
#                     work_field                 company  \
# 0                  Technology                   Amazon
# 1                  Technology                Microsoft
# 2     Finance and Investments       Berkshire Hathaway
# 3            Fashion & Retail                     Lvmh
# 4                  Technology                 Facebook
# ...                        ...                     ...
# 2203         Fashion & Retail   Fashion, Entertainment
# 2204            Manufacturing     Electrical Equipment
# 2205            Manufacturing     Electrical Equipment
# 2206            Manufacturing   Printed Circuit Boards
# 2207              Diversified              Diversified
#
#                                                   image             name  \
# 0     https://specials-images.forbesimg.com/imageser...       Jeff_Bezos
# 1     https://specials-images.forbesimg.com/imageser...       Bill_Gates
# 2     https://specials-images.forbesimg.com/imageser...   Warren_Buffett
# 3     https://specials-images.forbesimg.com/imageser...  Bernard_Arnault
# 4     https://specials-images.forbesimg.com/imageser...  Mark_Zuckerberg
# ...                                                 ...              ...
# 2203  https://specials-images.forbesimg.com/imageser...   Zhao_Xiaoqiang
# 2204  https://specials-images.forbesimg.com/imageser...  Zhou_Liangzhang
# 2205  https://specials-images.forbesimg.com/imageser...     Zhu_Xingming
# 2206  https://specials-images.forbesimg.com/imageser...         Jun_Zhuo
# 2207  https://specials-images.forbesimg.com/imageser...      Olgun_Zorlu
#
#      education
# 0         None
# 1         None
# 2         None
# 3         None
# 4         None
# ...        ...
# 2203      None
# 2204      None
# 2205      None
# 2206      None
# 2207      None
#
# [2208 rows x 14 columns]

# %%
colors = ['burlywood', 'yellowgreen', 'gold', 'r', 'orangered', 'mediumvioletred', 'skyblue', 'navy', 'grey', 'black']
df['age'].value_counts().plot(kind='hist', figsize=(20,10), color = colors)
plt.xlabel('Age (years)')
plt.ylabel('Number')
plt.title("Billionaire's age distribution")
plt.show()

# %%
for i in df['age']:
    if i<0:
        df['age'][i] =np.nan
df.hist(column='age',grid=False, bins=10000)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f9354d21750>]],
#       dtype=object)

# %%
df.describe()
# Out:
#           position          age  real_time_position  worth(BUSD)  \
# count  2208.000000  2208.000000         2208.000000  2208.000000
# mean   1104.500000     2.497736         1102.043478     4.103080
# std     637.539018   352.378150          630.218047     6.913084
# min       1.000000 -2019.000000            1.000000     1.000000
# 25%     552.750000    53.000000          555.750000     1.400000
# 50%    1104.500000    63.000000         1106.500000     2.200000
# 75%    1656.250000    73.000000         1655.250000     4.000000
# max    2208.000000    99.000000         2153.000000   112.000000
#
#        worth(millions_USD)
# count          2101.000000
# mean             -0.484737
# std              26.330360
# min            -672.311000
# 25%               0.000000
# 50%               0.000000
# 75%               0.000000
# max             530.206000

# %%
# Which country has maximum numbers of billionaires??
colors = ['burlywood', 'yellowgreen', 'gold', 'r', 'orangered', 'mediumvioletred', 'skyblue', 'navy', 'grey', 'black']
df['country'].value_counts()[:30].plot(kind='bar', width=0.9, figsize=(20,10), color = colors)
plt.xlabel('Country (Top 30)')
plt.ylabel('Number of billionaires')
plt.title('Number of billionaires per country')
# Out:
# Text(0.5, 1.0, 'Number of billionaires per country')

# %%
# Male to female ratio based on the total of dollares
male_female_ratio = df.groupby('gender')['worth(BUSD)'].sum().sort_values(ascending=False)/100

# In this case we will represent that variable in a pie chart:
gender = ['Male', 'Female']
colors = ['skyblue', 'hotpink']
male_female_ratio.plot(kind='pie', labels = gender, colors = colors, startangle=90, shadow=True, figsize=(20,10),  autopct='%.2f%%')
plt.title('Male-Female ratio')
plt.show()

# %%
# Which country has the greatest share in terms of total money held by its billionaires??
colors = ['burlywood', 'yellowgreen', 'gold', 'r', 'orangered', 'mediumvioletred', 'skyblue', 'navy', 'grey', 'black']
total_per_country = df.groupby('country')['worth(BUSD)'].sum().sort_values(ascending=False)[:15]
total_per_country.plot(kind='bar', width=0.92, figsize=(20,10), color = colors)
plt.xlabel('Country (Top 15)')
plt.ylabel('Billions of dollars')
plt.title('Top 15 countries which held more money')
plt.show()

# %%
# Top 10 most profitable field of work
most_profitable_work_field = df.groupby('work_field')['worth(BUSD)'].sum().sort_values(ascending=False)[:15]
most_profitable_work_field.plot(kind='bar', width=0.92, figsize=(20,10), color = colors)
plt.xlabel('Work field (Top 15)')
plt.ylabel('Billions of dollars')
plt.title('Top 10 most profitable fields of work')
plt.show()

# %%
edu_pie = df.education.value_counts()
edu = ['No', 'Yes']
edu_pie.plot(kind='pie', labels = edu, colors = colors, startangle=90, shadow=True, figsize=(20,10),  autopct='%.2f%%')
plt.title('Percentage of billionaires who have studies')
plt.show()
